# %%
import pyotp
import os

# %%
os.getenv('USER_EMAIL')

# %%
os.getenv('USER_PASSWORD')

# %%
# Initialize the TOTP object
totp = pyotp.TOTP(os.getenv('GBM_KEY'))

# Generate the Google Authenticator code
google_code = totp.now()

# %%
google_code
